# %% [markdown]
# ## Prototype LABELATOR
#
# ### overview.
# This notebook protypes a "labelator".  The purpose of a "labelator" is to easily create _cell types_ for "Probe" data.
#
# Currently we are prototyping with `scarches` to enable  SCVI / SCANVI models.  Crucially it is their anndata loader which is especially useful. AND to state our confirmation bias impliments the SCVI models which we like.
#
# We will validate potential models and calibrate them with simple expectations using a typical "Train" "Test" ("Validate") and "Probe" approach.
#
# Definitions:
# - "Train": data samples on which the model being tested is trained.
# - "Validate":  held-out samples, to test out-of-sample prediction fidelity.
# - "Probe": data generated elsewhere, which is _probing_ the fidelity of the model.
#
# ### Models:
# - SCVI
# - logistic regression
# - boosted trees (e.g. xgboost)
#
# ### Modules:
#
# - `data`: gene x barcode count matrices.  These will be packaged in anndata objects and leverage the scvi-tools / scarches framework for loading
# - `train`
# - `validate`
# - `probe`

# %% [markdown]
# ### Imports and scvi-tools installation (colab)

# %%
import sys

IN_COLAB = "google.colab" in sys.modules
if IN_COLAB:
    # !pip uninstall -y typing_extensions
    # !pip install --quiet scvi-colab
    from scvi_colab import install
    install()
    # !pip install --quiet scrublet

# %%
import sys
import warnings

import anndata as ad
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scanpy as sc
import scrublet as scr
import scvi
from pathlib import Path
# Out:
# /home/ergonyc/mambaforge/envs/scverse11/lib/python3.11/site-packages/scvi/_settings.py:63: UserWarning: Since v1.0.0, scvi-tools no longer uses a random seed by default. Run `scvi.settings.seed = 0` to reproduce results from previous versions.
#   self.seed = seed
# /home/ergonyc/mambaforge/envs/scverse11/lib/python3.11/site-packages/scvi/_settings.py:70: UserWarning: Setting `dl_pin_memory_gpu_training` is deprecated in v1.0 and will be removed in v1.1. Please pass in `pin_memory` to the data loaders instead.
#   self.dl_pin_memory_gpu_training = (

# %%
if IN_COLAB:
    from google.colab import drive
    drive.mount('/content/drive')

# %%
warnings.simplefilter(action="ignore", category=FutureWarning)


sc.set_figure_params(figsize=(4, 4))
scvi.settings.seed = 94705

# %config InlineBackend.print_figure_kwargs={'facecolor' : "w"}
# %config InlineBackend.figure_format='retina'
# Out:
# Global seed set to 94705

# %% [markdown]
# ## Data
#
# ### Load

# %%
XYLENA_ANNDATA = "brain_atlas_anndata.h5ad"
XYLENA_METADATA = "final_metadata.csv"
XYLENA_ANNDATA2 = "brain_atlas_counts.h5ad"

# %%
if IN_COLAB:
    root_path = Path("/content/drive/MyDrive/")
    data_path = root_path / "SingleCellModel/data"
else:
    root_path = Path("../")
    data_path = root_path / "data/scdata/xylena_raw"



data_file = data_path / XYLENA_ANNDATA

# %%
raw_ad = ad.read_h5ad(data_file)

# %%
ogfeatures = raw_ad.var_names.to_list()
raw_ad.var_names_make_unique()

# %%
features = raw_ad.var_names.tolist()

# %%
shared_feats = list(set(features) & set(ogfeatures))
len(shared_feats), len(features), len(ogfeatures)
# Out:
# (3000, 3000, 3000)

# %%
data_path / XYLENA_METADATA, Path.cwd()
# Out:
# (PosixPath('../data/scdata/xylena_raw/final_metadata.csv'),
#  PosixPath('/home/ergonyc/Projects/SingleCell/labelator/nbs'))

# %%
metadat = pd.read_csv(data_path / XYLENA_METADATA)
og_metadat = raw_ad.obs.copy()

# %%
metadat.head()
# Out:
#                   cells  doublet_score  nCount_RNA  nFeature_RNA  percent.mt  \
# 0  GGCCTAATCGATTTAG-1_1       0.163312       21670          6217    0.687587
# 1  TAGTAACGTAGTCAAT-1_1       0.143924       20190          5488    0.029718
# 2  GAAAGCCAGCAGCTCA-1_1       0.168777       17677          5687    0.797647
# 3  ACTCACCTCCTCCCTC-1_1       0.097057       17612          4954    0.062457
# 4  CTTCATCCAATCGCAC-1_1       0.120637       17250          4837    0.011594
#
#    percent.rb   batch        sample   S.Score  G2M.Score  ...      ExN1  \
# 0    0.562990  batch1  KEN-1070-ARC  0.003546  -0.010272  ...  0.746970
# 1    0.307083  batch1  KEN-1070-ARC  0.034954  -0.022838  ...  0.761065
# 2    0.543079  batch1  KEN-1070-ARC -0.021208  -0.012252  ...  0.879119
# 3    0.255508  batch1  KEN-1070-ARC -0.045867   0.005147  ...  0.893122
# 4    0.202899  batch1  KEN-1070-ARC -0.056202  -0.019759  ...  0.867374
#
#        InN2       MG3    Astro4    Oligo5      OPC6       VC7            type  \
# 0  0.029230 -0.121564 -0.421587 -0.665052 -0.169264 -0.119527  Mature neurons
# 1  0.038500 -0.098816 -0.455020 -0.384784 -0.388421  0.015812  Mature neurons
# 2  0.083963 -0.122479 -0.364199 -0.294441 -0.305501 -0.124843  Mature neurons
# 3  0.067002 -0.101790 -0.407095 -0.665777 -0.354619 -0.102641  Mature neurons
# 4  0.120805 -0.093970 -0.422024 -0.742585  0.131618 -0.095371  Mature neurons
#
#      UMAP_1     UMAP_2
# 0  1.518145 -11.242935
# 1  1.569603  -1.677851
# 2  6.405315   4.732371
# 3  1.445644  -1.882242
# 4  0.464842 -10.888965
#
# [5 rows x 23 columns]

# %%
obs = raw_ad.obs.copy()
obs.head()
# Out:
#                       seurat_clusters cell_type        sample
# cells
# GGCCTAATCGATTTAG-1_1                8       ExN  KEN-1070-ARC
# TAGTAACGTAGTCAAT-1_1                2       ExN  KEN-1070-ARC
# GAAAGCCAGCAGCTCA-1_1                2       ExN  KEN-1070-ARC
# ACTCACCTCCTCCCTC-1_1                2       ExN  KEN-1070-ARC
# CTTCATCCAATCGCAC-1_1                8       ExN  KEN-1070-ARC

# %%
newmeta = obs.join(metadat.set_index("cells"),lsuffix='', rsuffix='_other')
# tmp.head()
newmeta.head()
# Out:
#                       seurat_clusters cell_type        sample  doublet_score  \
# cells
# GGCCTAATCGATTTAG-1_1                8       ExN  KEN-1070-ARC       0.163312
# TAGTAACGTAGTCAAT-1_1                2       ExN  KEN-1070-ARC       0.143924
# GAAAGCCAGCAGCTCA-1_1                2       ExN  KEN-1070-ARC       0.168777
# ACTCACCTCCTCCCTC-1_1                2       ExN  KEN-1070-ARC       0.097057
# CTTCATCCAATCGCAC-1_1                8       ExN  KEN-1070-ARC       0.120637
#
#                       nCount_RNA  nFeature_RNA  percent.mt  percent.rb  \
# cells
# GGCCTAATCGATTTAG-1_1       21670          6217    0.687587    0.562990
# TAGTAACGTAGTCAAT-1_1       20190          5488    0.029718    0.307083
# GAAAGCCAGCAGCTCA-1_1       17677          5687    0.797647    0.543079
# ACTCACCTCCTCCCTC-1_1       17612          4954    0.062457    0.255508
# CTTCATCCAATCGCAC-1_1       17250          4837    0.011594    0.202899
#
#                        batch  sample_other  ...      ExN1      InN2       MG3  \
# cells                                       ...
# GGCCTAATCGATTTAG-1_1  batch1  KEN-1070-ARC  ...  0.746970  0.029230 -0.121564
# TAGTAACGTAGTCAAT-1_1  batch1  KEN-1070-ARC  ...  0.761065  0.038500 -0.098816
# GAAAGCCAGCAGCTCA-1_1  batch1  KEN-1070-ARC  ...  0.879119  0.083963 -0.122479
# ACTCACCTCCTCCCTC-1_1  batch1  KEN-1070-ARC  ...  0.893122  0.067002 -0.101790
# CTTCATCCAATCGCAC-1_1  batch1  KEN-1070-ARC  ...  0.867374  0.120805 -0.093970
#
#                         Astro4    Oligo5      OPC6       VC7            type  \
# cells
# GGCCTAATCGATTTAG-1_1 -0.421587 -0.665052 -0.169264 -0.119527  Mature neurons
# TAGTAACGTAGTCAAT-1_1 -0.455020 -0.384784 -0.388421  0.015812  Mature neurons
# GAAAGCCAGCAGCTCA-1_1 -0.364199 -0.294441 -0.305501 -0.124843  Mature neurons
# ACTCACCTCCTCCCTC-1_1 -0.407095 -0.665777 -0.354619 -0.102641  Mature neurons
# CTTCATCCAATCGCAC-1_1 -0.422024 -0.742585  0.131618 -0.095371  Mature neurons
#
#                         UMAP_1     UMAP_2
# cells
# GGCCTAATCGATTTAG-1_1  1.518145 -11.242935
# TAGTAACGTAGTCAAT-1_1  1.569603  -1.677851
# GAAAGCCAGCAGCTCA-1_1  6.405315   4.732371
# ACTCACCTCCTCCCTC-1_1  1.445644  -1.882242
# CTTCATCCAATCGCAC-1_1  0.464842 -10.888965
#
# [5 rows x 25 columns]

# %%
newmeta['sample'].value_counts()
# Out:
# KEN-1159-ARC      11317
# UMARY-5088-ARC    11247
# KEN-1066-ARC      10280
# SH-92-05-ARC       9325
# SH-03-15-ARC       9055
#                   ...
# UMARY-4727-ARC     1554
# UMARY-1465-ARC     1173
# UMARY-4263-ARC     1103
# UMARY-5028-ARC      828
# UMARY-1789-ARC      255
# Name: sample, Length: 138, dtype: int64

# %%
clean_samples_path = data_path / "Model Combinations - clean_samples_138.csv"
clean_samples = pd.read_csv(clean_samples_path)

# all_samples_path = "/content/drive/MyDrive/SingleCellModel/Model Combinations - all_samples_199.csv"
# all_samples = pd.read_csv(all_samples_path)

# dirty_samples_path = "/content/drive/MyDrive/SingleCellModel/Model Combinations - dirty_samples_61.csv"
# dirty_samples = pd.read_csv(dirty_samples_path)

test_samples_path = data_path / "Model Combinations - testing_set_41.csv"
test_samples = pd.read_csv(test_samples_path)

train_samples_path = data_path / "Model Combinations - training_set_98.csv"
train_samples = pd.read_csv(train_samples_path)
clean_samples.head()
# Out:
#          sample   batch
# 0  KEN-1070-ARC  batch1
# 1  KEN-1092-ARC  batch1
# 2  KEN-1095-ARC  batch1
# 3  KEN-1127-ARC  batch1
# 4  KEN-1132-ARC  batch1

# %%
newmeta['clean'] =  [s in set(clean_samples['sample']) for s in newmeta['sample'] ]
newmeta['test'] =  [s in set(test_samples['sample']) for s in newmeta['sample'] ]
newmeta['train'] =  [s in set(train_samples['sample']) for s in newmeta['sample'] ]

# %%
newmeta = newmeta.drop(columns=['seurat_clusters_other', 'sample_other'])
newmeta.head()
# Out:
#                       seurat_clusters cell_type        sample  doublet_score  \
# cells
# GGCCTAATCGATTTAG-1_1                8       ExN  KEN-1070-ARC       0.163312
# TAGTAACGTAGTCAAT-1_1                2       ExN  KEN-1070-ARC       0.143924
# GAAAGCCAGCAGCTCA-1_1                2       ExN  KEN-1070-ARC       0.168777
# ACTCACCTCCTCCCTC-1_1                2       ExN  KEN-1070-ARC       0.097057
# CTTCATCCAATCGCAC-1_1                8       ExN  KEN-1070-ARC       0.120637
#
#                       nCount_RNA  nFeature_RNA  percent.mt  percent.rb  \
# cells
# GGCCTAATCGATTTAG-1_1       21670          6217    0.687587    0.562990
# TAGTAACGTAGTCAAT-1_1       20190          5488    0.029718    0.307083
# GAAAGCCAGCAGCTCA-1_1       17677          5687    0.797647    0.543079
# ACTCACCTCCTCCCTC-1_1       17612          4954    0.062457    0.255508
# CTTCATCCAATCGCAC-1_1       17250          4837    0.011594    0.202899
#
#                        batch   S.Score  ...    Astro4    Oligo5      OPC6  \
# cells                                   ...
# GGCCTAATCGATTTAG-1_1  batch1  0.003546  ... -0.421587 -0.665052 -0.169264
# TAGTAACGTAGTCAAT-1_1  batch1  0.034954  ... -0.455020 -0.384784 -0.388421
# GAAAGCCAGCAGCTCA-1_1  batch1 -0.021208  ... -0.364199 -0.294441 -0.305501
# ACTCACCTCCTCCCTC-1_1  batch1 -0.045867  ... -0.407095 -0.665777 -0.354619
# CTTCATCCAATCGCAC-1_1  batch1 -0.056202  ... -0.422024 -0.742585  0.131618
#
#                            VC7            type    UMAP_1     UMAP_2  clean  \
# cells
# GGCCTAATCGATTTAG-1_1 -0.119527  Mature neurons  1.518145 -11.242935   True
# TAGTAACGTAGTCAAT-1_1  0.015812  Mature neurons  1.569603  -1.677851   True
# GAAAGCCAGCAGCTCA-1_1 -0.124843  Mature neurons  6.405315   4.732371   True
# ACTCACCTCCTCCCTC-1_1 -0.102641  Mature neurons  1.445644  -1.882242   True
# CTTCATCCAATCGCAC-1_1 -0.095371  Mature neurons  0.464842 -10.888965   True
#
#                        test  train
# cells
# GGCCTAATCGATTTAG-1_1  False   True
# TAGTAACGTAGTCAAT-1_1  False   True
# GAAAGCCAGCAGCTCA-1_1  False   True
# ACTCACCTCCTCCCTC-1_1  False   True
# CTTCATCCAATCGCAC-1_1  False   True
#
# [5 rows x 26 columns]

# %%
assert newmeta['clean'].sum() == raw_ad.shape[0]
# Out:
# True

# %%
# update anndata

adat = raw_ad.copy()
adat.obs = newmeta

# %%
adat[adat.obs['sample'] == adat.obs['sample'][0]].obs
# Out:
#                       seurat_clusters cell_type        sample  doublet_score  \
# cells
# GGCCTAATCGATTTAG-1_1                8       ExN  KEN-1070-ARC       0.163312
# TAGTAACGTAGTCAAT-1_1                2       ExN  KEN-1070-ARC       0.143924
# GAAAGCCAGCAGCTCA-1_1                2       ExN  KEN-1070-ARC       0.168777
# ACTCACCTCCTCCCTC-1_1                2       ExN  KEN-1070-ARC       0.097057
# CTTCATCCAATCGCAC-1_1                8       ExN  KEN-1070-ARC       0.120637
# ...                               ...       ...           ...            ...
# GCAGGACCATTAAACC-1_1                5        MG  KEN-1070-ARC       0.070043
# ACTAATCCAGGTATTT-1_1                0     Oligo  KEN-1070-ARC       0.163312
# AGTAGGATCACGCGGT-1_1               12     Oligo  KEN-1070-ARC       0.168777
# TGTCCTGGTTGGTTAG-1_1                5        MG  KEN-1070-ARC       0.174528
# CAAAGTGAGTAAGAAC-1_1                4       OPC  KEN-1070-ARC       0.050170
#
#                       nCount_RNA  nFeature_RNA  percent.mt  percent.rb  \
# cells
# GGCCTAATCGATTTAG-1_1       21670          6217    0.687587    0.562990
# TAGTAACGTAGTCAAT-1_1       20190          5488    0.029718    0.307083
# GAAAGCCAGCAGCTCA-1_1       17677          5687    0.797647    0.543079
# ACTCACCTCCTCCCTC-1_1       17612          4954    0.062457    0.255508
# CTTCATCCAATCGCAC-1_1       17250          4837    0.011594    0.202899
# ...                          ...           ...         ...         ...
# GCAGGACCATTAAACC-1_1        1001           764    0.999001    1.598402
# ACTAATCCAGGTATTT-1_1        1008           692    0.000000    0.595238
# AGTAGGATCACGCGGT-1_1        1001           685    0.000000    0.599401
# TGTCCTGGTTGGTTAG-1_1        1001           771    0.000000    0.999001
# CAAAGTGAGTAAGAAC-1_1        1004           737    0.000000    0.298805
#
#                        batch   S.Score  ...      ExN1      InN2       MG3  \
# cells                                   ...
# GGCCTAATCGATTTAG-1_1  batch1  0.003546  ...  0.746970  0.029230 -0.121564
# TAGTAACGTAGTCAAT-1_1  batch1  0.034954  ...  0.761065  0.038500 -0.098816
# GAAAGCCAGCAGCTCA-1_1  batch1 -0.021208  ...  0.879119  0.083963 -0.122479
# ACTCACCTCCTCCCTC-1_1  batch1 -0.045867  ...  0.893122  0.067002 -0.101790
# CTTCATCCAATCGCAC-1_1  batch1 -0.056202  ...  0.867374  0.120805 -0.093970
# ...                      ...       ...  ...       ...       ...       ...
# GCAGGACCATTAAACC-1_1  batch1 -0.041604  ... -0.287908 -0.118699  0.216093
# ACTAATCCAGGTATTT-1_1  batch1  0.033096  ... -0.369182 -0.112303 -0.026922
# AGTAGGATCACGCGGT-1_1  batch1 -0.028036  ... -0.413633 -0.091690 -0.024294
# TGTCCTGGTTGGTTAG-1_1  batch1 -0.004867  ... -0.038414 -0.142348  0.231241
# CAAAGTGAGTAAGAAC-1_1  batch1 -0.035658  ...  0.191374  0.188628 -0.040444
#
#                         Astro4    Oligo5      OPC6       VC7  \
# cells
# GGCCTAATCGATTTAG-1_1 -0.421587 -0.665052 -0.169264 -0.119527
# TAGTAACGTAGTCAAT-1_1 -0.455020 -0.384784 -0.388421  0.015812
# GAAAGCCAGCAGCTCA-1_1 -0.364199 -0.294441 -0.305501 -0.124843
# ACTCACCTCCTCCCTC-1_1 -0.407095 -0.665777 -0.354619 -0.102641
# CTTCATCCAATCGCAC-1_1 -0.422024 -0.742585  0.131618 -0.095371
# ...                        ...       ...       ...       ...
# GCAGGACCATTAAACC-1_1  0.128704 -0.088677 -0.164486 -0.087786
# ACTAATCCAGGTATTT-1_1  0.071956  1.165813 -0.149190 -0.043781
# AGTAGGATCACGCGGT-1_1 -0.248098  0.812266 -0.167344 -0.012075
# TGTCCTGGTTGGTTAG-1_1  0.299692  0.465222 -0.153135 -0.036226
# CAAAGTGAGTAAGAAC-1_1  0.175172 -0.465373  2.112989 -0.030154
#
#                                                  type    UMAP_1     UMAP_2
# cells
# GGCCTAATCGATTTAG-1_1                   Mature neurons  1.518145 -11.242935
# TAGTAACGTAGTCAAT-1_1                   Mature neurons  1.569603  -1.677851
# GAAAGCCAGCAGCTCA-1_1                   Mature neurons  6.405315   4.732371
# ACTCACCTCCTCCCTC-1_1                   Mature neurons  1.445644  -1.882242
# CTTCATCCAATCGCAC-1_1                   Mature neurons  0.464842 -10.888965
# ...                                               ...       ...        ...
# GCAGGACCATTAAACC-1_1                 Microglial cells  2.066342 -15.089943
# ACTAATCCAGGTATTT-1_1                 Oligodendrocytes  5.601439   9.173177
# AGTAGGATCACGCGGT-1_1                 Oligodendrocytes -5.065182  -2.298816
# TGTCCTGGTTGGTTAG-1_1                 Microglial cells  0.696901 -15.475661
# CAAAGTGAGTAAGAAC-1_1  Oligodendrocyte precursor cells -5.692689  -8.827646
#
# [3866 rows x 23 columns]

# %%
# do this to hedge against empty var isues

adat.var['feat'] = adat.var_names

# %%
outfilen = data_path / XYLENA_ANNDATA.replace(".h5ad", "_updated.h5ad")

adat.write_h5ad(outfilen)

# %% [markdown]
# # make train and validation adatas

# %%
train_ad = adat[adat.obs['train']].copy()
val_ad = adat[adat.obs['test']].copy()

outfilen = data_path / XYLENA_ANNDATA.replace(".h5ad", "_train.h5ad")
train_ad.write_h5ad(outfilen)

outfilen = data_path / XYLENA_ANNDATA.replace(".h5ad", "_val.h5ad")
val_ad.write_h5ad(outfilen)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[122], line 9
#       6 train_ad.write_h5ad(outfilen)
#       8 outfilen = data_path / XYLENA_ANNDATA.replace(".h5ad", "_test.h5ad")
# ----> 9 test_ad.write_h5ad(outfilen)
#
# NameError: name 'test_ad' is not defined

# %% [markdown]
# ## Preprocessing
#
# We might need to make some auxillary metadata for the dataset. We will use the cell type annotations from the original paper, and we will also make a cell type annotation for the doublets.

# %% [markdown]
# ### Train, Validate

# %% [markdown]
# ## Model
#
# ### Train
#
# ### Validate with

# %% [markdown]
# ### Reference mapping with SCVI
