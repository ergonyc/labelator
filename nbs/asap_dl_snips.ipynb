# %%
# !gsutil -u dnastack-asap-parkinsons ls -al gs://asap-raw-data-team-lee/workflow_execution/preprocess/cellranger/1.0.0
# Out:
#    4182329  2023-09-28T14:54:36Z  gs://asap-raw-data-team-lee/workflow_execution/preprocess/cellranger/1.0.0/HIP_HC_0602.filtered_feature_bc_matrix.h5#1695912876110619  metageneration=1
#        675  2023-10-25T13:38:12Z  gs://asap-raw-data-team-lee/workflow_execution/preprocess/cellranger/1.0.0/HIP_HC_0602.metrics_summary.csv#1698241092634728  metageneration=1
#   46207406  2023-09-28T14:54:36Z  gs://asap-raw-data-team-lee/workflow_execution/preprocess/cellranger/1.0.0/HIP_HC_0602.molecule_info.h5#1695912876065222  metageneration=1
#   14315619  2023-09-28T14:54:36Z  gs://asap-raw-data-team-lee/workflow_execution/preprocess/cellranger/1.0.0/HIP_HC_0602.raw_feature_bc_matrix.h5#1695912876065073  metageneration=1
#   10902247  2023-09-28T14:54:36Z  gs://asap-raw-data-team-lee/workflow_execution/preprocess/cellranger/1.0.0/HIP_HC_1225.filtered_feature_bc_matrix.h5#1695912876061139  metageneration=1
# ...

# %%
# !gsutil -u dnastack-asap-parkinsons ls gs://asap-raw-data-team-lee/workflow_execution/preprocess/cellranger/1.0.0/
# Out:
# gs://asap-raw-data-team-lee/workflow_execution/preprocess/cellranger/1.0.0/HIP_HC_0602.filtered_feature_bc_matrix.h5
# gs://asap-raw-data-team-lee/workflow_execution/preprocess/cellranger/1.0.0/HIP_HC_0602.metrics_summary.csv
# gs://asap-raw-data-team-lee/workflow_execution/preprocess/cellranger/1.0.0/HIP_HC_0602.molecule_info.h5
# gs://asap-raw-data-team-lee/workflow_execution/preprocess/cellranger/1.0.0/HIP_HC_0602.raw_feature_bc_matrix.h5
# gs://asap-raw-data-team-lee/workflow_execution/preprocess/cellranger/1.0.0/HIP_HC_1225.filtered_feature_bc_matrix.h5
# gs://asap-raw-data-team-lee/workflow_execution/preprocess/cellranger/1.0.0/HIP_HC_1225.metrics_summary.csv
# gs://asap-raw-data-team-lee/workflow_execution/preprocess/cellranger/1.0.0/HIP_HC_1225.molecule_info.h5
# gs://asap-raw-data-team-lee/workflow_execution/preprocess/cellranger/1.0.0/HIP_HC_1225.raw_feature_bc_matrix.h5
# ...

# %%
gsutil -m -u dnastack-asap-parkinsons cp -r  "gs://asap-raw-data-team-lee/workflow_execution/preprocess/cellranger/1.0.0/" \
      "/home/ergonyc/Projects/SingleCell/scdata/ASAP/team-lee/raw/"

# %%
mkdir ASAP/team-hafler
mkdir ASAP/team-hafler/raw
mkdir ASAP/team-hardy
mkdir ASAP/team-hardy/raw
mkdir ASAP/team-jakobsson
mkdir ASAP/team-jakobsson/raw

# %%
# !gcloud auth login
# Out:
# Your browser has been opened to visit:
#
#     https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=32555940559.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A8085%2F&scope=openid+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fuserinfo.email+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fcloud-platform+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fappengine.admin+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fsqlservice.login+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fcompute+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Faccounts.reauth&state=HkArD9je05eTmiYq1lxhJ5zHvFxSq5&access_type=offline&code_challenge=secMcAhdFhPQTCMQwCoXD5DK8eg9mmsWISZ_n2Bqvpg&code_challenge_method=S256
#
#
# You are now logged in as [henrie@datatecnica.com].
# Your current project is [None].  You can change this setting by running:
#   $ gcloud config set project PROJECT_ID

# %%
# !gcloud auth activate-service-account --key-file=$HOME/Projects/ASAP/hafler-credentials.json
# !gsutil -u dnastack-asap-parkinsons ls -al gs://asap-raw-data-team-hafler
# Out:
# Activated service account credentials for: [raw-admin-hafler@dnastack-asap-parkinsons.iam.gserviceaccount.com]
#         20  2023-08-15T15:09:35Z  gs://asap-raw-data-team-hafler/test-hafler.txt#1692112175417434  metageneration=1
#         20  2023-08-15T15:13:26Z  gs://asap-raw-data-team-hafler/test-raw-hafler.txt#1692112406419193  metageneration=1
#       5214  2023-08-15T15:09:40Z  gs://asap-raw-data-team-hafler/testfile.txt#1692112180915732  metageneration=1
#                                  gs://asap-raw-data-team-hafler/fastqs/
#                                  gs://asap-raw-data-team-hafler/metadata/
#                                  gs://asap-raw-data-team-hafler/workflow_execution/
# TOTAL: 3 objects, 5254 bytes (5.13 KiB)

# %%
# !gsutil -u dnastack-asap-parkinsons ls -al gs://asap-raw-data-team-hafler/workflow_execution/preprocess/cellranger/1.1.0/
# Out:
#   24889398  2023-12-09T05:13:03Z  gs://asap-raw-data-team-hafler/workflow_execution/preprocess/cellranger/1.1.0/ASAP_PMBDS_000026_s001_Rep1.filtered_feature_bc_matrix.h5#1702098783893580  metageneration=1
#        651  2023-12-09T05:13:03Z  gs://asap-raw-data-team-hafler/workflow_execution/preprocess/cellranger/1.1.0/ASAP_PMBDS_000026_s001_Rep1.metrics_summary.csv#1702098783327168  metageneration=1
#  322029016  2023-12-09T05:13:09Z  gs://asap-raw-data-team-hafler/workflow_execution/preprocess/cellranger/1.1.0/ASAP_PMBDS_000026_s001_Rep1.molecule_info.h5#1702098789309551  metageneration=1
#   55272924  2023-12-09T05:13:04Z  gs://asap-raw-data-team-hafler/workflow_execution/preprocess/cellranger/1.1.0/ASAP_PMBDS_000026_s001_Rep1.raw_feature_bc_matrix.h5#1702098784171625  metageneration=1
# ...

# %%
gcloud auth activate-service-account --key-file=$HOME/Projects/ASAP/hardy-credentials.json

# !gsutil -u dnastack-asap-parkinsons ls -al gs://asap-raw-data-team-hardy/workflow_execution/preprocess/cellranger/1.1.0

# %%
# !gcloud auth activate-service-account --key-file=$HOME/Projects/ASAP/jakobsson-credentials.json

# !gsutil -u dnastack-asap-parkinsons ls -al gs://asap-raw-data-team-jakobsson/

# gsutil -m -u dnastack-asap-parkinsons ls  "gs://asap-raw-data-team-jakobsson/CRN_snRNA/artifacts/cellranger_counts"
# Out:
# Activated service account credentials for: [raw-admin-jakobsson@dnastack-asap-parkinsons.iam.gserviceaccount.com]
#         20  2023-08-15T15:13:57Z  gs://asap-raw-data-team-jakobsson/test-raw-jakobsson.txt#1692112437671820  metageneration=1
#                                  gs://asap-raw-data-team-jakobsson/artifacts/
#                                  gs://asap-raw-data-team-jakobsson/fastqs/
#                                  gs://asap-raw-data-team-jakobsson/metadata/
#                                  gs://asap-raw-data-team-jakobsson/ogmetadata/
#                                  gs://asap-raw-data-team-jakobsson/scripts/
#                                  gs://asap-raw-data-team-jakobsson/workflow_execution/
# TOTAL: 1 objects, 20 bytes (20 B)

# %%
# !gcloud auth activate-service-account --key-file=$HOME/Projects/ASAP/jakobsson-credentials.json

# !gsutil -u dnastack-asap-parkinsons ls -al gs://asap-raw-data-team-jakobsson/workflow_execution/preprocess/cellranger/1.1.0/
# Out:
#    1911417  2023-12-08T23:36:17Z  gs://asap-raw-data-team-jakobsson/workflow_execution/preprocess/cellranger/1.1.0/ASAP_PMBDS_000102_s001_1.filtered_feature_bc_matrix.h5#1702078577301936  metageneration=1
#        648  2023-12-08T23:36:17Z  gs://asap-raw-data-team-jakobsson/workflow_execution/preprocess/cellranger/1.1.0/ASAP_PMBDS_000102_s001_1.metrics_summary.csv#1702078577233948  metageneration=1
#   33453929  2023-12-08T23:36:17Z  gs://asap-raw-data-team-jakobsson/workflow_execution/preprocess/cellranger/1.1.0/ASAP_PMBDS_000102_s001_1.molecule_info.h5#1702078577841992  metageneration=1
#    8580975  2023-12-08T23:36:17Z  gs://asap-raw-data-team-jakobsson/workflow_execution/preprocess/cellranger/1.1.0/ASAP_PMBDS_000102_s001_1.raw_feature_bc_matrix.h5#1702078577515923  metageneration=1
# ...

# %%
# !gcloud auth activate-service-account --key-file=$HOME/Projects/ASAP/sulzer-credentials.json

# !gsutil -u dnastack-asap-parkinsons ls -al gs://asap-raw-data-team-sulzer/workflow_execution/preprocess/cellranger/1.1.0/
# Out:
# Activated service account credentials for: [raw-admin-sulzer@dnastack-asap-parkinsons.iam.gserviceaccount.com]
#   83806108  2023-12-09T03:17:54Z  gs://asap-raw-data-team-sulzer/workflow_execution/preprocess/cellranger/1.1.0/ASAP_PMBDS_000221_s001_Rep1.filtered_feature_bc_matrix.h5#1702091874085892  metageneration=1
#        648  2023-12-09T03:17:52Z  gs://asap-raw-data-team-sulzer/workflow_execution/preprocess/cellranger/1.1.0/ASAP_PMBDS_000221_s001_Rep1.metrics_summary.csv#1702091872636469  metageneration=1
#  487774802  2023-12-09T03:18:02Z  gs://asap-raw-data-team-sulzer/workflow_execution/preprocess/cellranger/1.1.0/ASAP_PMBDS_000221_s001_Rep1.molecule_info.h5#1702091882057754  metageneration=1
#  123990951  2023-12-09T03:17:54Z  gs://asap-raw-data-team-sulzer/workflow_execution/preprocess/cellranger/1.1.0/ASAP_PMBDS_000221_s001_Rep1.raw_feature_bc_matrix.h5#1702091874781675  metageneration=1
# ...

# %%
# !gcloud auth activate-service-account --key-file=$HOME/Projects/ASAP/scherzer-credentials.json

# !gsutil -u dnastack-asap-parkinsons ls -al gs://asap-raw-data-team-scherzer/workflow_execution/preprocess/cellranger/1.1.0/
# Out:
# Activated service account credentials for: [raw-admin-scherzer@dnastack-asap-parkinsons.iam.gserviceaccount.com]
#   12124929  2023-12-09T01:32:28Z  gs://asap-raw-data-team-scherzer/workflow_execution/preprocess/cellranger/1.1.0/ASAP_PMBDS_000002_s004_rep1.filtered_feature_bc_matrix.h5#1702085548010963  metageneration=1
#        651  2023-12-09T01:32:27Z  gs://asap-raw-data-team-scherzer/workflow_execution/preprocess/cellranger/1.1.0/ASAP_PMBDS_000002_s004_rep1.metrics_summary.csv#1702085547740481  metageneration=1
#  144539041  2023-12-09T01:32:31Z  gs://asap-raw-data-team-scherzer/workflow_execution/preprocess/cellranger/1.1.0/ASAP_PMBDS_000002_s004_rep1.molecule_info.h5#1702085551436844  metageneration=1
#   31009564  2023-12-09T01:32:28Z  gs://asap-raw-data-team-scherzer/workflow_execution/preprocess/cellranger/1.1.0/ASAP_PMBDS_000002_s004_rep1.raw_feature_bc_matrix.h5#1702085548140163  metageneration=1
# ...
